# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
trade_df = spark.read.option(
    "header",
    "true"
).csv(
    "Files/data/raw/nse_trade_hist",
    inferSchema=True
)

display(
    trade_df
    .filter(
        trade_df.Symbol == "PIDILITIND"
    )
    .orderBy("Date")
)
# Out:
# StatementMeta(, 0413e6bb-0390-49ac-9b5c-fb6ebea65001, 12, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f549f6f9-5cd5-48b5-9d85-04dfcd072fb8)

# %%
import pandas as pd
trade_df = spark.read.option(
    "header",
    "true"
).csv(
    "Files/data/raw/bse_trade_hist",
    inferSchema=True
)

trade_df.columns
# Out:
# StatementMeta(, 0413e6bb-0390-49ac-9b5c-fb6ebea65001, 13, Finished, Available, Finished, False)
# ['Symbol', 'Date', 'Close', 'High', 'Low', 'Open', 'Volume']

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
trade_df = spark.read.option(
    "header",
    "true"
).csv(
    "Files/data/raw/bse_trade_hist",
    inferSchema=True
)

display(
    trade_df
    .filter(
        trade_df.Symbol == "PIDILITIND"
    )
    .orderBy("Date")
)
# Out:
# StatementMeta(, 0413e6bb-0390-49ac-9b5c-fb6ebea65001, 14, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, beec0366-6722-41f8-9fdd-c8f6ac26eeaf)
